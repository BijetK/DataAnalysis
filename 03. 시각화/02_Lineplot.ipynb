# %% [markdown]
# ## 라인 플룻

# %%
# !apt-get install -y fonts-nanum > /dev/null
# !fc-cache -fv > dev/null
# !rm -rf ~/.cache.matplotlib > dev/null
# Out:
# /bin/bash: dev/null: No such file or directory
# /bin/bash: dev/null: No such file or directory

# %% [markdown]
# ### 반드시 런타임 재시작!!!

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['axes.unicode_minus'] = False
plt.rc('font', family = 'NanumBarunGothic')
# %matplotlib inline        주피터 노트북에서 그래프를 볼 때 사용하는 매직 명령어

# %%
plt.title('플롯 예')
plt.plot([0, 1, 4, 9])
plt.grid()
plt.show()

# %%
plt.title("라인 플룻")
xs = np.linspace(0, 3, 301)
ys = (xs + 1) ** 2
plt.plot(xs,ys)     # y = (x + 1) ** 2
plt.grid()
plt.show()

# %% [markdown]
# ## 스타일 지정

# %%
# 색깔(r), 마커(s), 선스타일(--)
plt.title("'rs--' 스타일의 plot ")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], 'rs--')
plt.grid()
plt.show()

# %%
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], c='#199c6e',
         lw=5, ls="--", marker="o", ms=15, mec="g", mew=5, mfc="r")
plt.title("스타일 적용 예")
plt.show()

# %% [markdown]
# ## 그림범위 지정

# %%
plt.title("x축, y축의 범위 설정")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16],
         c="#199c6e", lw=5, ls="--", marker="o", ms=15, mec="g", mew=5, mfc="r")
plt.xlim(0, 50)
plt.ylim(-10, 30)
plt.grid()
plt.show()

# %%
plt.title("x축, y축의 범위 설정")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16],
         c="#199c6e", lw=5, ls="--", marker="o", ms=15, mec="g", mew=5, mfc="r")
plt.xlim(0, 50)
plt.ylim(-2, 20)
plt.grid()
plt.show()

# %% [markdown]
# ## 틱 설정

# %%
X = np.linspace(-np.pi, np.pi, 256)
C = np.cos(X)
plt.title("x축과 y축의 tick label 설정")
plt.plot(X, C)
plt.xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
plt.yticks([-1, 0, +1])
plt.grid()
plt.show()

# %%
# 틱 라벨 문자열에는 $$ 사이에 LaTeX 수학 문자식을 넣을 수도 있다.
X = np.linspace(-np.pi, np.pi, 256)
C = np.cos(X)
plt.title("LaTeX, 문자열로 tick label 정의")
plt.plot(X, C)
plt.xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi],
           [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1, 0, 1], ["Low", "Zero", "High"])
plt.grid()
plt.show()

# %% [markdown]
# ## 여러개의 선을 그리기

# %%
t = np.arange(0., 5., 0.2)
plt.title("라인 플롯에서 여러개의 선 그리기")
plt.plot(t, t, 'r--', t, 0.5 * t**2, 'bs:', t, 0.2 * t**3, 'g^-')
plt.grid()
plt.show()

# %% [markdown]
# ### 겹쳐그리기

# %%
# 한번에 쓰려 하지 말고, 따로따로 쓰는게 이해하기도 더 쉽다!

t = np.arange(0., 5., 0.2)
plt.title("라인 플롯에서 여러개의 선 그리기")
plt.plot(t, t, 'r--')
plt.plot(t, 0.5 * t**2, 'bs:')
plt.plot(t, 0.2 * t**3, 'g^-')
plt.grid()
plt.show()

# %% [markdown]
# ### 범례(Legend)

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.title("legend를 표시한 플롯")
plt.plot(X, C, label="cosine")     # 라벨을 지정해야 범례에 표시됨
plt.plot(X, S, ls=":", label="sine")        # 라벨을 지정해야 범례에 표시됨
plt.legend(loc='lower center')
plt.grid()
plt.show()

# %% [markdown]
# ### x축, y축 라벨, 타이틀

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.plot(X, C, label="cosine")
plt.xlabel("time")
plt.ylabel("amplitude")
plt.title("Cosine Plot")
plt.grid()
plt.show()
